# %% [markdown]
# ## This notebook makes "CMB-augmented" catalogs.
#
# It takes around **10 minutes** to run.
#
# Input files from previous pipeline stages:
#   - `xl_ge_gg.txt`: Power spectra $P_{ge}(k)$, $P_{gg}(k)$.
#   - `wcmb_90.fits` and `wcmb_150.fits`: CMB pixel weight function $W_{\rm cmb}(\theta)$.
#   - `fl_90.txt`, `fl_150.txt`: CMB harmonic-space weight function $F_l$.
#
# First, we read the following catalogs:
#   - SDSS galaxy catalog (CMASS_North, DR12)
#   - Corresponding random catalog
#   - 1000 mock catalogs (CMASS_North, DR12, QPM)
#   - Corresponding mock random catalog
#
# Second, for each catalog, we add the following columns:
#   - `tcmb_90`: filtered CMB temperature at location of each galaxy, 90 GHz
#   - `tcmb_150`: filtered CMB temperature at location of each galaxy, 150 GHz
#   - `bv_90`: per-galaxy velocity reconstruction bias $b_v$, 90 GHz
#   - `bv_150`: per-galaxy velocity reconstruction bias $b_v$, 150 GHz
#
# where $b_v$ is the per-object velocity reconstruction, which we compute in the approximation (see overleaf):
#
# $$\begin{align}
# b_v(\theta,\chi) &\approx B_v(\chi) \, W_{\rm CMB}(\theta) \\
# B_v(\chi) &= \frac{K(\chi)}{\chi^2} \sum_l \frac{2l+1}{4\pi} b_l F_l \, P_{ge}^{\rm true}(k,\chi)_{k=l/\chi} \\
# K(z) &= -T_{\rm CMB} \, \sigma_T \, n_{e0} \, x_e(z) \, e^{-\tau(z)} \, (1+z)^2
# \end{align}$$
#
# Third, we write the catalogs to disk in an hdf5 file format:
#   - Galaxy catalog -> `catalogs/galaxies.h5`
#   - Random catalog -> `catalogs/randoms.h5`
#   - Mock catalog -> `catalogs/mock_{i}.h5`, where $0 \le i < 1000$.
#   - Mock random catalog -> `catalogs/mock_randoms.h5`
#
# Finally, we write two miscellaneous files that will be convenient in later pipeline stages:
#   - `bounding_box.pkl`: bounding box of random catalog (instance of class `kszx.BoundingBox`)
#   - `ngal_mock.npy`: 1-d numpy array of length nmocks, containing number of galaxies in each mock
#
# After this script has been run, we don't need to process the CMB maps (or CMB data products such as $W_{\rm cmb}(\theta)$, $F_l$) again. Subsequent pipeline stages can work entirely with "augmented" catalogs, with a few numbers $T_{90}, T_{150}, b_v^{90}, b_v^{150}$ per galaxy.

# %% [markdown]
# ## Imports and global variables

# %%
import kszx
import pixell
import numpy as np
import matplotlib.pyplot as plt

# %%
# File 'global_params.py' in current directory
import global_params

lmax = global_params.ksz_lmax
act_dr = global_params.act_dr

survey = global_params.sdss_survey
rpad = global_params.sdss_rpad
pixsize = global_params.sdss_pixsize
zmin = global_params.sdss_zmin
zmax = global_params.sdss_zmax
zeff = global_params.sdss_zeff
mock_type = global_params.sdss_mock_type
nmocks = global_params.sdss_nmocks

# %%
cosmo = kszx.Cosmology('planck18+bao')
# Out:
# Running CAMB

# %% [markdown]
# ## Read input files and process CMB maps

# %%
def read_cl(filename, col):
    fl = np.loadtxt(filename)
    assert fl.ndim == 2
    assert len(fl) == lmax+1
    assert np.all(fl[:,0] == np.arange(lmax+1))
    return fl[:,col]

xl_ge = read_cl('xl_ge_gg.txt', col=1)

# %%
def prepare_freq(freq):
    """Returns pair of pixell maps (tcmb, bv)."""

    bl = kszx.act.read_beam(freq, dr=5, lmax=lmax)
    fl = read_cl(f'fl_{freq}.txt', col=1)

    l = np.arange(lmax+1)
    B = np.sum((2*l+1)/(4*np.pi) * bl * fl * xl_ge)
    B *= cosmo.K(z=zeff) / cosmo.chi(z=zeff)**2
    
    wcmb = kszx.pixell_utils.read_map(f'wcmb_{freq}.fits')
    bv = B * wcmb
    
    tcmb = kszx.act.read_cmb(freq, dr=act_dr, download=True)
    tcmb *= wcmb
    alm = kszx.pixell_utils.map2alm(tcmb, lmax)
    alm = pixell.curvedsky.almxfl(alm, fl)
    tcmb = kszx.pixell_utils.alm2map(alm, tcmb.shape, tcmb.wcs)

    return tcmb, bv

# %%
tcmb_90, bv_90 = prepare_freq(90)
tcmb_150, bv_150 = prepare_freq(150)
# Out:
# kszx: environment variable $KSZX_DATA_DIR not defined, using /home/kmsmith/kszx_data instead
# Reading /home/kmsmith/kszx_data/act/dr5.01/beams/act_planck_dr5.01_s08s18_f090_daynight_beam.txt
# Reading wcmb_90.fits
# Reading /home/kmsmith/kszx_data/act/dr5.01/act_planck_dr5.01_s08s18_AA_f090_daynight_map_srcfree.fits
# Reading /home/kmsmith/kszx_data/act/dr5.01/beams/act_planck_dr5.01_s08s18_f150_daynight_beam.txt
# Reading wcmb_150.fits
# Reading /home/kmsmith/kszx_data/act/dr5.01/act_planck_dr5.01_s08s18_AA_f150_daynight_map_srcfree.fits

# %% [markdown]
# ## Define function process_catalog() that will be run on all catalogs/randoms/mocks

# %%
def process_catalog(catalog, output_filename):
    catalog.apply_redshift_cut(zmin, zmax)

    cols = [ ('tcmb_90',tcmb_90), ('tcmb_150',tcmb_150), ('bv_90',bv_90), ('bv_150',bv_150) ]
    
    for col_name, pixell_map in cols:
        t = kszx.pixell_utils.eval_map_on_catalog(pixell_map, catalog, pad=0.0)
        catalog.add_column(col_name, t)
    
    catalog.write_h5(output_filename)

# %% [markdown]
# ## Process galaxy catalog

# %%
gcat = kszx.sdss.read_galaxies(survey, download=True)
process_catalog(gcat, 'catalogs/galaxies.h5')
# Out:
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/galaxy_DR12v5_CMASS_North.fits
# Read 618806 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/galaxy_DR12v5_CMASS_North.fits, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wcp', 'wzf', 'wsys', 'cboss', 'id']
# Reminder: you probably want to call cat.apply_redshift_cut(zmin,zmax) on the Catalog returned by kszx.sdss.read_galaxies())
# Redshift cut: zmin=0.43 zmax=0.7: 618806 -> 568776 [91.915% retained]
# Writing catalogs/galaxies.h5
# Wrote 568776 galaxies to catalogs/galaxies.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wcp', 'wzf', 'wsys', 'cboss', 'id', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']

# %% [markdown]
# ## Process random catalog (and write bounding box)

# %%
rcat = kszx.sdss.read_randoms(survey, download=True)
process_catalog(rcat, 'catalogs/randoms.h5')

box = kszx.BoundingBox(rcat.get_xyz(cosmo), pixsize, rpad)
kszx.io_utils.write_pickle('bounding_box.pkl', box)
print('\n', box)
# Out:
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/random0_DR12v5_CMASS_North.fits
# Read 32151741 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/random0_DR12v5_CMASS_North.fits, columns ['ra_deg', 'dec_deg', 'z', 'wfkp']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/random1_DR12v5_CMASS_North.fits
# Read 32151250 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/random1_DR12v5_CMASS_North.fits, columns ['ra_deg', 'dec_deg', 'z', 'wfkp']
# Reminder: you probably want to call cat.apply_redshift_cut(zmin,zmax) on the Catalog returned by kszx.sdss.read_randoms())
# Redshift cut: zmin=0.43 zmax=0.7: 64302991 -> 59175065 [92.025% retained]
# Writing catalogs/randoms.h5
# CMASS_North randoms: Wrote 59175065 galaxies to catalogs/randoms.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Writing bounding_box.pkl
#
#  BoundingBox(
#     npix = [320 576 320],
#     pixsize = 10.0,
#     boxsize = [3200. 5760. 3200.],
#     kfund = [0.0019635  0.00109083 0.0019635 ],
#     knyq = 0.3141592653589793,
#     lpos = [-2963.38860096 -2935.1527411   -475.07298616],
#     cpos = [-1368.38860096   -60.1527411   1119.92701384],
#     rpos = [ 226.61139904 2814.8472589  2714.92701384]
#     rpad = 500.00,
#     rmin = 1706.22, rmax = 2579.23,
#     npix_prepad = [243 464 257],
#     npix_preround = [293 514 307]
# )

# %% [markdown]
# ## Process mock random catalog

# %%
mrcat = kszx.sdss.read_mock_randoms(survey, mock_type, download=True)
process_catalog(mrcat, 'catalogs/mock_randoms.h5')
# Out:
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_random_DR12_CMASS_N_50x1.rdzw
# mock_random_DR12_CMASS_N_50x1.rdzw: Read 32292068 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_random_DR12_CMASS_N_50x1.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_random_DR12_CMASS_N_50x2.rdzw
# mock_random_DR12_CMASS_N_50x2.rdzw: Read 32298915 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_random_DR12_CMASS_N_50x2.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp']
# Redshift cut: zmin=0.43 zmax=0.7: 64590983 -> 64590983 [100.0% retained]
# Writing catalogs/mock_randoms.h5
# CMASS_North qpm mock randoms: Wrote 64590983 galaxies to catalogs/mock_randoms.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']

# %% [markdown]
# ## Process mocks (and write mock_ngal.npy)

# %%
# %%time

mock_ngal = np.zeros(nmocks)

for i in range(nmocks):
    mcat = kszx.sdss.read_mock(survey, mock_type, i, download=True)
    process_catalog(mcat, f'catalogs/mock_{i}.h5')
    mock_ngal[i] = mcat.size

kszx.io_utils.write_npy('mock_ngal.npy', mock_ngal)
# Out:
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0001.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0001.rdzw: Read 642051 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0001.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 642051 -> 642051 [100.0% retained]
# Writing catalogs/mock_0.h5
# mock_galaxy_DR12_CMASS_N_QPM_0001.rdzw: Wrote 642051 galaxies to catalogs/mock_0.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0002.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0002.rdzw: Read 652204 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0002.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652204 -> 652204 [100.0% retained]
# Writing catalogs/mock_1.h5
# mock_galaxy_DR12_CMASS_N_QPM_0002.rdzw: Wrote 652204 galaxies to catalogs/mock_1.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0003.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0003.rdzw: Read 648000 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0003.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648000 -> 648000 [100.0% retained]
# Writing catalogs/mock_2.h5
# mock_galaxy_DR12_CMASS_N_QPM_0003.rdzw: Wrote 648000 galaxies to catalogs/mock_2.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0004.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0004.rdzw: Read 653168 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0004.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653168 -> 653168 [100.0% retained]
# Writing catalogs/mock_3.h5
# mock_galaxy_DR12_CMASS_N_QPM_0004.rdzw: Wrote 653168 galaxies to catalogs/mock_3.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0005.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0005.rdzw: Read 651360 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0005.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651360 -> 651360 [100.0% retained]
# Writing catalogs/mock_4.h5
# mock_galaxy_DR12_CMASS_N_QPM_0005.rdzw: Wrote 651360 galaxies to catalogs/mock_4.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0006.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0006.rdzw: Read 647624 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0006.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 647624 -> 647624 [100.0% retained]
# Writing catalogs/mock_5.h5
# mock_galaxy_DR12_CMASS_N_QPM_0006.rdzw: Wrote 647624 galaxies to catalogs/mock_5.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0007.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0007.rdzw: Read 656533 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0007.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 656533 -> 656533 [100.0% retained]
# Writing catalogs/mock_6.h5
# mock_galaxy_DR12_CMASS_N_QPM_0007.rdzw: Wrote 656533 galaxies to catalogs/mock_6.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0008.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0008.rdzw: Read 650279 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0008.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650279 -> 650279 [100.0% retained]
# Writing catalogs/mock_7.h5
# mock_galaxy_DR12_CMASS_N_QPM_0008.rdzw: Wrote 650279 galaxies to catalogs/mock_7.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0009.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0009.rdzw: Read 651894 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0009.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651894 -> 651894 [100.0% retained]
# Writing catalogs/mock_8.h5
# mock_galaxy_DR12_CMASS_N_QPM_0009.rdzw: Wrote 651894 galaxies to catalogs/mock_8.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0010.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0010.rdzw: Read 651286 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0010.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651286 -> 651286 [100.0% retained]
# Writing catalogs/mock_9.h5
# mock_galaxy_DR12_CMASS_N_QPM_0010.rdzw: Wrote 651286 galaxies to catalogs/mock_9.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0011.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0011.rdzw: Read 652503 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0011.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652503 -> 652503 [100.0% retained]
# Writing catalogs/mock_10.h5
# mock_galaxy_DR12_CMASS_N_QPM_0011.rdzw: Wrote 652503 galaxies to catalogs/mock_10.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0012.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0012.rdzw: Read 650373 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0012.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650373 -> 650373 [100.0% retained]
# Writing catalogs/mock_11.h5
# mock_galaxy_DR12_CMASS_N_QPM_0012.rdzw: Wrote 650373 galaxies to catalogs/mock_11.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0013.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0013.rdzw: Read 652804 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0013.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652804 -> 652804 [100.0% retained]
# Writing catalogs/mock_12.h5
# mock_galaxy_DR12_CMASS_N_QPM_0013.rdzw: Wrote 652804 galaxies to catalogs/mock_12.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0014.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0014.rdzw: Read 653476 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0014.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653476 -> 653476 [100.0% retained]
# Writing catalogs/mock_13.h5
# mock_galaxy_DR12_CMASS_N_QPM_0014.rdzw: Wrote 653476 galaxies to catalogs/mock_13.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0015.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0015.rdzw: Read 651248 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0015.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651248 -> 651248 [100.0% retained]
# Writing catalogs/mock_14.h5
# mock_galaxy_DR12_CMASS_N_QPM_0015.rdzw: Wrote 651248 galaxies to catalogs/mock_14.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0016.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0016.rdzw: Read 653526 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0016.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653526 -> 653526 [100.0% retained]
# Writing catalogs/mock_15.h5
# mock_galaxy_DR12_CMASS_N_QPM_0016.rdzw: Wrote 653526 galaxies to catalogs/mock_15.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0017.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0017.rdzw: Read 648160 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0017.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648160 -> 648160 [100.0% retained]
# Writing catalogs/mock_16.h5
# mock_galaxy_DR12_CMASS_N_QPM_0017.rdzw: Wrote 648160 galaxies to catalogs/mock_16.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0018.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0018.rdzw: Read 646726 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0018.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 646726 -> 646726 [100.0% retained]
# Writing catalogs/mock_17.h5
# mock_galaxy_DR12_CMASS_N_QPM_0018.rdzw: Wrote 646726 galaxies to catalogs/mock_17.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0019.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0019.rdzw: Read 657431 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0019.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 657431 -> 657431 [100.0% retained]
# Writing catalogs/mock_18.h5
# mock_galaxy_DR12_CMASS_N_QPM_0019.rdzw: Wrote 657431 galaxies to catalogs/mock_18.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0020.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0020.rdzw: Read 648384 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0020.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648384 -> 648384 [100.0% retained]
# Writing catalogs/mock_19.h5
# mock_galaxy_DR12_CMASS_N_QPM_0020.rdzw: Wrote 648384 galaxies to catalogs/mock_19.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0021.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0021.rdzw: Read 653666 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0021.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653666 -> 653666 [100.0% retained]
# Writing catalogs/mock_20.h5
# mock_galaxy_DR12_CMASS_N_QPM_0021.rdzw: Wrote 653666 galaxies to catalogs/mock_20.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0022.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0022.rdzw: Read 648765 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0022.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648765 -> 648765 [100.0% retained]
# Writing catalogs/mock_21.h5
# mock_galaxy_DR12_CMASS_N_QPM_0022.rdzw: Wrote 648765 galaxies to catalogs/mock_21.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0023.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0023.rdzw: Read 657790 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0023.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 657790 -> 657790 [100.0% retained]
# Writing catalogs/mock_22.h5
# mock_galaxy_DR12_CMASS_N_QPM_0023.rdzw: Wrote 657790 galaxies to catalogs/mock_22.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0024.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0024.rdzw: Read 654977 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0024.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 654977 -> 654977 [100.0% retained]
# Writing catalogs/mock_23.h5
# mock_galaxy_DR12_CMASS_N_QPM_0024.rdzw: Wrote 654977 galaxies to catalogs/mock_23.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0025.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0025.rdzw: Read 650596 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0025.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650596 -> 650596 [100.0% retained]
# Writing catalogs/mock_24.h5
# mock_galaxy_DR12_CMASS_N_QPM_0025.rdzw: Wrote 650596 galaxies to catalogs/mock_24.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0026.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0026.rdzw: Read 653351 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0026.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653351 -> 653351 [100.0% retained]
# Writing catalogs/mock_25.h5
# mock_galaxy_DR12_CMASS_N_QPM_0026.rdzw: Wrote 653351 galaxies to catalogs/mock_25.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0027.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0027.rdzw: Read 653762 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0027.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653762 -> 653762 [100.0% retained]
# Writing catalogs/mock_26.h5
# mock_galaxy_DR12_CMASS_N_QPM_0027.rdzw: Wrote 653762 galaxies to catalogs/mock_26.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0028.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0028.rdzw: Read 656250 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0028.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 656250 -> 656250 [100.0% retained]
# Writing catalogs/mock_27.h5
# mock_galaxy_DR12_CMASS_N_QPM_0028.rdzw: Wrote 656250 galaxies to catalogs/mock_27.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0029.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0029.rdzw: Read 650032 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0029.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650032 -> 650032 [100.0% retained]
# Writing catalogs/mock_28.h5
# mock_galaxy_DR12_CMASS_N_QPM_0029.rdzw: Wrote 650032 galaxies to catalogs/mock_28.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0030.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0030.rdzw: Read 655889 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0030.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 655889 -> 655889 [100.0% retained]
# Writing catalogs/mock_29.h5
# mock_galaxy_DR12_CMASS_N_QPM_0030.rdzw: Wrote 655889 galaxies to catalogs/mock_29.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0031.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0031.rdzw: Read 647276 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0031.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 647276 -> 647276 [100.0% retained]
# Writing catalogs/mock_30.h5
# mock_galaxy_DR12_CMASS_N_QPM_0031.rdzw: Wrote 647276 galaxies to catalogs/mock_30.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0032.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0032.rdzw: Read 651509 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0032.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651509 -> 651509 [100.0% retained]
# Writing catalogs/mock_31.h5
# mock_galaxy_DR12_CMASS_N_QPM_0032.rdzw: Wrote 651509 galaxies to catalogs/mock_31.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0033.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0033.rdzw: Read 649692 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0033.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 649692 -> 649692 [100.0% retained]
# Writing catalogs/mock_32.h5
# mock_galaxy_DR12_CMASS_N_QPM_0033.rdzw: Wrote 649692 galaxies to catalogs/mock_32.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0034.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0034.rdzw: Read 651350 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0034.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651350 -> 651350 [100.0% retained]
# Writing catalogs/mock_33.h5
# mock_galaxy_DR12_CMASS_N_QPM_0034.rdzw: Wrote 651350 galaxies to catalogs/mock_33.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0035.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0035.rdzw: Read 653694 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0035.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653694 -> 653694 [100.0% retained]
# Writing catalogs/mock_34.h5
# mock_galaxy_DR12_CMASS_N_QPM_0035.rdzw: Wrote 653694 galaxies to catalogs/mock_34.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0036.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0036.rdzw: Read 652580 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0036.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652580 -> 652580 [100.0% retained]
# Writing catalogs/mock_35.h5
# mock_galaxy_DR12_CMASS_N_QPM_0036.rdzw: Wrote 652580 galaxies to catalogs/mock_35.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0037.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0037.rdzw: Read 652258 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0037.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652258 -> 652258 [100.0% retained]
# Writing catalogs/mock_36.h5
# mock_galaxy_DR12_CMASS_N_QPM_0037.rdzw: Wrote 652258 galaxies to catalogs/mock_36.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0038.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0038.rdzw: Read 650616 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0038.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650616 -> 650616 [100.0% retained]
# Writing catalogs/mock_37.h5
# mock_galaxy_DR12_CMASS_N_QPM_0038.rdzw: Wrote 650616 galaxies to catalogs/mock_37.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0039.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0039.rdzw: Read 652706 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0039.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652706 -> 652706 [100.0% retained]
# Writing catalogs/mock_38.h5
# mock_galaxy_DR12_CMASS_N_QPM_0039.rdzw: Wrote 652706 galaxies to catalogs/mock_38.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0040.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0040.rdzw: Read 651134 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0040.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651134 -> 651134 [100.0% retained]
# Writing catalogs/mock_39.h5
# mock_galaxy_DR12_CMASS_N_QPM_0040.rdzw: Wrote 651134 galaxies to catalogs/mock_39.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0041.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0041.rdzw: Read 651925 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0041.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651925 -> 651925 [100.0% retained]
# Writing catalogs/mock_40.h5
# mock_galaxy_DR12_CMASS_N_QPM_0041.rdzw: Wrote 651925 galaxies to catalogs/mock_40.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0042.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0042.rdzw: Read 644705 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0042.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 644705 -> 644705 [100.0% retained]
# Writing catalogs/mock_41.h5
# mock_galaxy_DR12_CMASS_N_QPM_0042.rdzw: Wrote 644705 galaxies to catalogs/mock_41.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0043.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0043.rdzw: Read 655537 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0043.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 655537 -> 655537 [100.0% retained]
# Writing catalogs/mock_42.h5
# mock_galaxy_DR12_CMASS_N_QPM_0043.rdzw: Wrote 655537 galaxies to catalogs/mock_42.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0044.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0044.rdzw: Read 658008 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0044.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 658008 -> 658008 [100.0% retained]
# Writing catalogs/mock_43.h5
# mock_galaxy_DR12_CMASS_N_QPM_0044.rdzw: Wrote 658008 galaxies to catalogs/mock_43.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0045.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0045.rdzw: Read 648389 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0045.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648389 -> 648389 [100.0% retained]
# Writing catalogs/mock_44.h5
# mock_galaxy_DR12_CMASS_N_QPM_0045.rdzw: Wrote 648389 galaxies to catalogs/mock_44.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0046.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0046.rdzw: Read 653791 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0046.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653791 -> 653791 [100.0% retained]
# Writing catalogs/mock_45.h5
# mock_galaxy_DR12_CMASS_N_QPM_0046.rdzw: Wrote 653791 galaxies to catalogs/mock_45.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0047.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0047.rdzw: Read 652770 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0047.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652770 -> 652770 [100.0% retained]
# Writing catalogs/mock_46.h5
# mock_galaxy_DR12_CMASS_N_QPM_0047.rdzw: Wrote 652770 galaxies to catalogs/mock_46.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0048.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0048.rdzw: Read 646161 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0048.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 646161 -> 646161 [100.0% retained]
# Writing catalogs/mock_47.h5
# mock_galaxy_DR12_CMASS_N_QPM_0048.rdzw: Wrote 646161 galaxies to catalogs/mock_47.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0049.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0049.rdzw: Read 653441 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0049.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653441 -> 653441 [100.0% retained]
# Writing catalogs/mock_48.h5
# mock_galaxy_DR12_CMASS_N_QPM_0049.rdzw: Wrote 653441 galaxies to catalogs/mock_48.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0050.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0050.rdzw: Read 654451 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0050.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 654451 -> 654451 [100.0% retained]
# Writing catalogs/mock_49.h5
# mock_galaxy_DR12_CMASS_N_QPM_0050.rdzw: Wrote 654451 galaxies to catalogs/mock_49.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0051.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0051.rdzw: Read 653189 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0051.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653189 -> 653189 [100.0% retained]
# Writing catalogs/mock_50.h5
# mock_galaxy_DR12_CMASS_N_QPM_0051.rdzw: Wrote 653189 galaxies to catalogs/mock_50.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0052.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0052.rdzw: Read 653135 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0052.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653135 -> 653135 [100.0% retained]
# Writing catalogs/mock_51.h5
# mock_galaxy_DR12_CMASS_N_QPM_0052.rdzw: Wrote 653135 galaxies to catalogs/mock_51.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0053.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0053.rdzw: Read 651184 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0053.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651184 -> 651184 [100.0% retained]
# Writing catalogs/mock_52.h5
# mock_galaxy_DR12_CMASS_N_QPM_0053.rdzw: Wrote 651184 galaxies to catalogs/mock_52.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0054.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0054.rdzw: Read 654728 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0054.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 654728 -> 654728 [100.0% retained]
# Writing catalogs/mock_53.h5
# mock_galaxy_DR12_CMASS_N_QPM_0054.rdzw: Wrote 654728 galaxies to catalogs/mock_53.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0055.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0055.rdzw: Read 654040 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0055.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 654040 -> 654040 [100.0% retained]
# Writing catalogs/mock_54.h5
# mock_galaxy_DR12_CMASS_N_QPM_0055.rdzw: Wrote 654040 galaxies to catalogs/mock_54.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0056.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0056.rdzw: Read 644628 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0056.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 644628 -> 644628 [100.0% retained]
# Writing catalogs/mock_55.h5
# mock_galaxy_DR12_CMASS_N_QPM_0056.rdzw: Wrote 644628 galaxies to catalogs/mock_55.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0057.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0057.rdzw: Read 650523 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0057.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650523 -> 650523 [100.0% retained]
# Writing catalogs/mock_56.h5
# mock_galaxy_DR12_CMASS_N_QPM_0057.rdzw: Wrote 650523 galaxies to catalogs/mock_56.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0058.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0058.rdzw: Read 652901 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0058.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652901 -> 652901 [100.0% retained]
# Writing catalogs/mock_57.h5
# mock_galaxy_DR12_CMASS_N_QPM_0058.rdzw: Wrote 652901 galaxies to catalogs/mock_57.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0059.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0059.rdzw: Read 656220 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0059.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 656220 -> 656220 [100.0% retained]
# Writing catalogs/mock_58.h5
# mock_galaxy_DR12_CMASS_N_QPM_0059.rdzw: Wrote 656220 galaxies to catalogs/mock_58.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0060.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0060.rdzw: Read 646231 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0060.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 646231 -> 646231 [100.0% retained]
# Writing catalogs/mock_59.h5
# mock_galaxy_DR12_CMASS_N_QPM_0060.rdzw: Wrote 646231 galaxies to catalogs/mock_59.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0061.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0061.rdzw: Read 650667 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0061.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650667 -> 650667 [100.0% retained]
# Writing catalogs/mock_60.h5
# mock_galaxy_DR12_CMASS_N_QPM_0061.rdzw: Wrote 650667 galaxies to catalogs/mock_60.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0062.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0062.rdzw: Read 649632 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0062.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 649632 -> 649632 [100.0% retained]
# Writing catalogs/mock_61.h5
# mock_galaxy_DR12_CMASS_N_QPM_0062.rdzw: Wrote 649632 galaxies to catalogs/mock_61.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0063.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0063.rdzw: Read 646573 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0063.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 646573 -> 646573 [100.0% retained]
# Writing catalogs/mock_62.h5
# mock_galaxy_DR12_CMASS_N_QPM_0063.rdzw: Wrote 646573 galaxies to catalogs/mock_62.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0064.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0064.rdzw: Read 646595 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0064.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 646595 -> 646595 [100.0% retained]
# Writing catalogs/mock_63.h5
# mock_galaxy_DR12_CMASS_N_QPM_0064.rdzw: Wrote 646595 galaxies to catalogs/mock_63.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0065.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0065.rdzw: Read 650299 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0065.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650299 -> 650299 [100.0% retained]
# Writing catalogs/mock_64.h5
# mock_galaxy_DR12_CMASS_N_QPM_0065.rdzw: Wrote 650299 galaxies to catalogs/mock_64.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0066.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0066.rdzw: Read 648400 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0066.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648400 -> 648400 [100.0% retained]
# Writing catalogs/mock_65.h5
# mock_galaxy_DR12_CMASS_N_QPM_0066.rdzw: Wrote 648400 galaxies to catalogs/mock_65.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0067.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0067.rdzw: Read 648579 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0067.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648579 -> 648579 [100.0% retained]
# Writing catalogs/mock_66.h5
# mock_galaxy_DR12_CMASS_N_QPM_0067.rdzw: Wrote 648579 galaxies to catalogs/mock_66.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0068.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0068.rdzw: Read 648831 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0068.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648831 -> 648831 [100.0% retained]
# Writing catalogs/mock_67.h5
# mock_galaxy_DR12_CMASS_N_QPM_0068.rdzw: Wrote 648831 galaxies to catalogs/mock_67.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0069.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0069.rdzw: Read 648753 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0069.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648753 -> 648753 [100.0% retained]
# Writing catalogs/mock_68.h5
# mock_galaxy_DR12_CMASS_N_QPM_0069.rdzw: Wrote 648753 galaxies to catalogs/mock_68.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0070.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0070.rdzw: Read 656896 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0070.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 656896 -> 656896 [100.0% retained]
# Writing catalogs/mock_69.h5
# mock_galaxy_DR12_CMASS_N_QPM_0070.rdzw: Wrote 656896 galaxies to catalogs/mock_69.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0071.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0071.rdzw: Read 652592 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0071.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652592 -> 652592 [100.0% retained]
# Writing catalogs/mock_70.h5
# mock_galaxy_DR12_CMASS_N_QPM_0071.rdzw: Wrote 652592 galaxies to catalogs/mock_70.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0072.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0072.rdzw: Read 644348 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0072.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 644348 -> 644348 [100.0% retained]
# Writing catalogs/mock_71.h5
# mock_galaxy_DR12_CMASS_N_QPM_0072.rdzw: Wrote 644348 galaxies to catalogs/mock_71.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0073.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0073.rdzw: Read 651571 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0073.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651571 -> 651571 [100.0% retained]
# Writing catalogs/mock_72.h5
# mock_galaxy_DR12_CMASS_N_QPM_0073.rdzw: Wrote 651571 galaxies to catalogs/mock_72.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0074.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0074.rdzw: Read 652188 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0074.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652188 -> 652188 [100.0% retained]
# Writing catalogs/mock_73.h5
# mock_galaxy_DR12_CMASS_N_QPM_0074.rdzw: Wrote 652188 galaxies to catalogs/mock_73.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0075.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0075.rdzw: Read 651209 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0075.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651209 -> 651209 [100.0% retained]
# Writing catalogs/mock_74.h5
# mock_galaxy_DR12_CMASS_N_QPM_0075.rdzw: Wrote 651209 galaxies to catalogs/mock_74.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0076.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0076.rdzw: Read 656181 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0076.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 656181 -> 656181 [100.0% retained]
# Writing catalogs/mock_75.h5
# mock_galaxy_DR12_CMASS_N_QPM_0076.rdzw: Wrote 656181 galaxies to catalogs/mock_75.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0077.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0077.rdzw: Read 654490 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0077.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 654490 -> 654490 [100.0% retained]
# Writing catalogs/mock_76.h5
# mock_galaxy_DR12_CMASS_N_QPM_0077.rdzw: Wrote 654490 galaxies to catalogs/mock_76.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0078.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0078.rdzw: Read 653571 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0078.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653571 -> 653571 [100.0% retained]
# Writing catalogs/mock_77.h5
# mock_galaxy_DR12_CMASS_N_QPM_0078.rdzw: Wrote 653571 galaxies to catalogs/mock_77.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0079.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0079.rdzw: Read 653488 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0079.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653488 -> 653488 [100.0% retained]
# Writing catalogs/mock_78.h5
# mock_galaxy_DR12_CMASS_N_QPM_0079.rdzw: Wrote 653488 galaxies to catalogs/mock_78.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0080.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0080.rdzw: Read 646341 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0080.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 646341 -> 646341 [100.0% retained]
# Writing catalogs/mock_79.h5
# mock_galaxy_DR12_CMASS_N_QPM_0080.rdzw: Wrote 646341 galaxies to catalogs/mock_79.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0081.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0081.rdzw: Read 650632 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0081.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650632 -> 650632 [100.0% retained]
# Writing catalogs/mock_80.h5
# mock_galaxy_DR12_CMASS_N_QPM_0081.rdzw: Wrote 650632 galaxies to catalogs/mock_80.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0082.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0082.rdzw: Read 652377 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0082.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652377 -> 652377 [100.0% retained]
# Writing catalogs/mock_81.h5
# mock_galaxy_DR12_CMASS_N_QPM_0082.rdzw: Wrote 652377 galaxies to catalogs/mock_81.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0083.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0083.rdzw: Read 645166 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0083.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 645166 -> 645166 [100.0% retained]
# Writing catalogs/mock_82.h5
# mock_galaxy_DR12_CMASS_N_QPM_0083.rdzw: Wrote 645166 galaxies to catalogs/mock_82.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0084.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0084.rdzw: Read 653496 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0084.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653496 -> 653496 [100.0% retained]
# ...
# Redshift cut: zmin=0.43 zmax=0.7: 652260 -> 652260 [100.0% retained]
# Writing catalogs/mock_972.h5
# mock_galaxy_DR12_CMASS_N_QPM_0973.rdzw: Wrote 652260 galaxies to catalogs/mock_972.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0974.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0974.rdzw: Read 659524 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0974.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 659524 -> 659524 [100.0% retained]
# Writing catalogs/mock_973.h5
# mock_galaxy_DR12_CMASS_N_QPM_0974.rdzw: Wrote 659524 galaxies to catalogs/mock_973.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0975.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0975.rdzw: Read 650803 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0975.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650803 -> 650803 [100.0% retained]
# Writing catalogs/mock_974.h5
# mock_galaxy_DR12_CMASS_N_QPM_0975.rdzw: Wrote 650803 galaxies to catalogs/mock_974.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0976.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0976.rdzw: Read 646126 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0976.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 646126 -> 646126 [100.0% retained]
# Writing catalogs/mock_975.h5
# mock_galaxy_DR12_CMASS_N_QPM_0976.rdzw: Wrote 646126 galaxies to catalogs/mock_975.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0977.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0977.rdzw: Read 652596 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0977.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652596 -> 652596 [100.0% retained]
# Writing catalogs/mock_976.h5
# mock_galaxy_DR12_CMASS_N_QPM_0977.rdzw: Wrote 652596 galaxies to catalogs/mock_976.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0978.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0978.rdzw: Read 651175 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0978.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651175 -> 651175 [100.0% retained]
# Writing catalogs/mock_977.h5
# mock_galaxy_DR12_CMASS_N_QPM_0978.rdzw: Wrote 651175 galaxies to catalogs/mock_977.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0979.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0979.rdzw: Read 651183 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0979.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651183 -> 651183 [100.0% retained]
# Writing catalogs/mock_978.h5
# mock_galaxy_DR12_CMASS_N_QPM_0979.rdzw: Wrote 651183 galaxies to catalogs/mock_978.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0980.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0980.rdzw: Read 649737 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0980.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 649737 -> 649737 [100.0% retained]
# Writing catalogs/mock_979.h5
# mock_galaxy_DR12_CMASS_N_QPM_0980.rdzw: Wrote 649737 galaxies to catalogs/mock_979.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0981.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0981.rdzw: Read 650251 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0981.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650251 -> 650251 [100.0% retained]
# Writing catalogs/mock_980.h5
# mock_galaxy_DR12_CMASS_N_QPM_0981.rdzw: Wrote 650251 galaxies to catalogs/mock_980.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0982.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0982.rdzw: Read 645722 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0982.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 645722 -> 645722 [100.0% retained]
# Writing catalogs/mock_981.h5
# mock_galaxy_DR12_CMASS_N_QPM_0982.rdzw: Wrote 645722 galaxies to catalogs/mock_981.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0983.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0983.rdzw: Read 647692 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0983.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 647692 -> 647692 [100.0% retained]
# Writing catalogs/mock_982.h5
# mock_galaxy_DR12_CMASS_N_QPM_0983.rdzw: Wrote 647692 galaxies to catalogs/mock_982.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0984.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0984.rdzw: Read 650327 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0984.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650327 -> 650327 [100.0% retained]
# Writing catalogs/mock_983.h5
# mock_galaxy_DR12_CMASS_N_QPM_0984.rdzw: Wrote 650327 galaxies to catalogs/mock_983.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0985.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0985.rdzw: Read 649305 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0985.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 649305 -> 649305 [100.0% retained]
# Writing catalogs/mock_984.h5
# mock_galaxy_DR12_CMASS_N_QPM_0985.rdzw: Wrote 649305 galaxies to catalogs/mock_984.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0986.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0986.rdzw: Read 653091 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0986.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653091 -> 653091 [100.0% retained]
# Writing catalogs/mock_985.h5
# mock_galaxy_DR12_CMASS_N_QPM_0986.rdzw: Wrote 653091 galaxies to catalogs/mock_985.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0987.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0987.rdzw: Read 648399 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0987.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648399 -> 648399 [100.0% retained]
# Writing catalogs/mock_986.h5
# mock_galaxy_DR12_CMASS_N_QPM_0987.rdzw: Wrote 648399 galaxies to catalogs/mock_986.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0988.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0988.rdzw: Read 650039 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0988.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650039 -> 650039 [100.0% retained]
# Writing catalogs/mock_987.h5
# mock_galaxy_DR12_CMASS_N_QPM_0988.rdzw: Wrote 650039 galaxies to catalogs/mock_987.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0989.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0989.rdzw: Read 651619 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0989.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651619 -> 651619 [100.0% retained]
# Writing catalogs/mock_988.h5
# mock_galaxy_DR12_CMASS_N_QPM_0989.rdzw: Wrote 651619 galaxies to catalogs/mock_988.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0990.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0990.rdzw: Read 653040 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0990.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 653040 -> 653040 [100.0% retained]
# Writing catalogs/mock_989.h5
# mock_galaxy_DR12_CMASS_N_QPM_0990.rdzw: Wrote 653040 galaxies to catalogs/mock_989.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0991.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0991.rdzw: Read 650748 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0991.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650748 -> 650748 [100.0% retained]
# Writing catalogs/mock_990.h5
# mock_galaxy_DR12_CMASS_N_QPM_0991.rdzw: Wrote 650748 galaxies to catalogs/mock_990.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0992.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0992.rdzw: Read 649027 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0992.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 649027 -> 649027 [100.0% retained]
# Writing catalogs/mock_991.h5
# mock_galaxy_DR12_CMASS_N_QPM_0992.rdzw: Wrote 649027 galaxies to catalogs/mock_991.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0993.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0993.rdzw: Read 655754 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0993.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 655754 -> 655754 [100.0% retained]
# Writing catalogs/mock_992.h5
# mock_galaxy_DR12_CMASS_N_QPM_0993.rdzw: Wrote 655754 galaxies to catalogs/mock_992.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0994.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0994.rdzw: Read 648332 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0994.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 648332 -> 648332 [100.0% retained]
# Writing catalogs/mock_993.h5
# mock_galaxy_DR12_CMASS_N_QPM_0994.rdzw: Wrote 648332 galaxies to catalogs/mock_993.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0995.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0995.rdzw: Read 652238 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0995.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 652238 -> 652238 [100.0% retained]
# Writing catalogs/mock_994.h5
# mock_galaxy_DR12_CMASS_N_QPM_0995.rdzw: Wrote 652238 galaxies to catalogs/mock_994.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0996.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0996.rdzw: Read 649403 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0996.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 649403 -> 649403 [100.0% retained]
# Writing catalogs/mock_995.h5
# mock_galaxy_DR12_CMASS_N_QPM_0996.rdzw: Wrote 649403 galaxies to catalogs/mock_995.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0997.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0997.rdzw: Read 654157 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0997.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 654157 -> 654157 [100.0% retained]
# Writing catalogs/mock_996.h5
# mock_galaxy_DR12_CMASS_N_QPM_0997.rdzw: Wrote 654157 galaxies to catalogs/mock_996.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0998.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0998.rdzw: Read 651565 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0998.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 651565 -> 651565 [100.0% retained]
# Writing catalogs/mock_997.h5
# mock_galaxy_DR12_CMASS_N_QPM_0998.rdzw: Wrote 651565 galaxies to catalogs/mock_997.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0999.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_0999.rdzw: Read 650303 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_0999.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 650303 -> 650303 [100.0% retained]
# Writing catalogs/mock_998.h5
# mock_galaxy_DR12_CMASS_N_QPM_0999.rdzw: Wrote 650303 galaxies to catalogs/mock_998.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Reading /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_1000.rdzw
# mock_galaxy_DR12_CMASS_N_QPM_1000.rdzw: Read 656503 galaxies from /home/kmsmith/kszx_data/sdss/DR12v5/qpm_mocks/mock_galaxy_DR12_CMASS_N_QPM_1000.rdzw, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto']
# Redshift cut: zmin=0.43 zmax=0.7: 656503 -> 656503 [100.0% retained]
# Writing catalogs/mock_999.h5
# mock_galaxy_DR12_CMASS_N_QPM_1000.rdzw: Wrote 656503 galaxies to catalogs/mock_999.h5, columns ['ra_deg', 'dec_deg', 'z', 'wfkp', 'wveto', 'tcmb_90', 'tcmb_150', 'bv_90', 'bv_150']
# Writing mock_ngal.npy
# CPU times: user 6min 20s, sys: 59 s, total: 7min 19s
# Wall time: 7min 22s
